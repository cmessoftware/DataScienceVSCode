# %% [markdown]
# ![Image in a markdown cell](https://cursos.utnba.centrodeelearning.com/pluginfile.php/1/theme_space/customlogo/1738330016/Logo%20UTN%20Horizontal.png)

# %% [markdown]
# ---

# %% [markdown]
# # **Diplomado en Ciencia de datos**

# %% [markdown]
# # **Actividades Tema 4: Visualización de Datos**

# %% [markdown]
# **Instrucciones:**
#
# Esta actividad tiene como objetivo evaluar tu comprensión de las librerías Matplotlib y Seaborn en Python.
# Utilizarás un dataset creado directamente en el notebook para crear diferentes tipos de gráficos.
#
# Sigue las instrucciones cuidadosamente y escribe el código necesario para cada tarea.

# %% [markdown]
# ## Importación de librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Creación del Dataset
# * Crea un DataFrame llamado 'df' con los siguientes datos:
#    - 'Categoría': ['A', 'B', 'C', 'A', 'B', 'C', 'A', 'B', 'C']
#    - 'Valor1': [10, 15, 7, 12, 18, 9, 14, 20, 11]
#    - 'Valor2': [5, 8, 3, 6, 10, 4, 7, 12, 5]

# %%
# Creación del DataFrame
df = pd.DataFrame({
    'Categoría': ['A', 'B', 'C', 'A', 'B', 'C', 'A', 'B', 'C'],
    'Valor1': [10, 15, 7, 12, 18, 9, 14, 20, 11],
    'Valor2': [5, 8, 3, 6, 10, 4, 7, 12, 5]
})
df
# Out:
#   Categoría  Valor1  Valor2
# 0         A      10       5
# 1         B      15       8
# 2         C       7       3
# 3         A      12       6
# 4         B      18      10
# 5         C       9       4
# 6         A      14       7
# 7         B      20      12
# 8         C      11       5

# %% [markdown]
# ## 2. Gráfico de Líneas (Matplotlib)
# * Crea un gráfico de líneas que muestre la evolución de 'Valor1' a lo largo del índice del DataFrame.
# * Agrega un título al gráfico y etiquetas a los ejes.

# %%
# Gráfico de líneas para mostrar la evolución de 'Valor1'
plt.figure(figsize=(8, 5))
plt.plot(df.index, df['Valor1'], marker='o', linestyle='-', color='b', label='Valor1')
plt.title('Evolución de Valor1 a lo largo del índice', fontsize=14)
plt.xlabel('Índice', fontsize=12)
plt.ylabel('Valor1', fontsize=12)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## 3. Gráfico de Barras (Matplotlib)
# * Crea un gráfico de barras que muestre la suma de 'Valor1' para cada 'Categoría'.
# * Agrega un título al gráfico y etiquetas a los ejes.

# %%
plt.figure(figsize=(8, 5))
plt.bar(df['Categoría'], df['Valor1'], color='skyblue')
plt.title('Distribución de Valor1 por Categoría', fontsize=14)
plt.xlabel('Categoría', fontsize=12)
plt.ylabel('Valor1', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ## 4. Diagrama de Dispersión (Matplotlib)
# * Crea un diagrama de dispersión que muestre la relación entre 'Valor1' y 'Valor2'.
# * Agrega un título al gráfico y etiquetas a los ejes.

# %%
# Diagrama de dispersión para mostrar la relación entre 'Valor1' y 'Valor2'
plt.figure(figsize=(8, 5))
plt.scatter(df['Valor1'], df['Valor2'], color='purple', alpha=0.7)
plt.title('Relación entre Valor1 y Valor2', fontsize=14)
plt.xlabel('Valor1', fontsize=12)
plt.ylabel('Valor2', fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# ## 5. Histograma (Matplotlib)
# * Crea un histograma que muestre la distribución de 'Valor1'.
# * Agrega un título al gráfico y etiquetas a los ejes.

# %%
# Histograma para mostrar la distribución de 'Valor1'
plt.figure(figsize=(8, 5))
plt.hist(df['Valor1'], bins=5, color='orange', edgecolor='black', alpha=0.7)
plt.title('Distribución de Valor1', fontsize=14)
plt.xlabel('Valor1', fontsize=12)
plt.ylabel('Frecuencia', fontsize=12)
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# ## 6. Diagrama de Caja (Matplotlib)
# * Crea un diagrama de caja que muestre la distribución de 'Valor1' para cada 'Categoría'.
# * Agrega un título al gráfico y etiquetas a los ejes.

# %%
# Diagrama de caja para mostrar la distribución de 'Valor1' para cada 'Categoría'
plt.figure(figsize=(8, 5))
sns.boxplot(x='Categoría', y='Valor1', data=df, palette='pastel')
plt.title('Distribución de Valor1 por Categoría', fontsize=14)
plt.xlabel('Categoría', fontsize=12)
sns.boxplot(x='Categoría', y='Valor1', data=df, hue='Categoría', palette='pastel', dodge=False, legend=False)
plt.grid(axis='y', alpha=0.75)
plt.show()
# Out:
# /tmp/ipykernel_751/1580629037.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Categoría', y='Valor1', data=df, palette='pastel')

# %% [markdown]
# # 7. Gráfico de Barras Agrupadas (Seaborn)
# * Utiliza Seaborn para crear un gráfico de barras agrupadas que muestre la media de 'Valor1' y 'Valor2' para cada 'Categoría'.
# * Agrega un título al gráfico.

# %%
# Gráfico de barras agrupadas para mostrar la media de 'Valor1' y 'Valor2' por 'Categoría'
plt.figure(figsize=(8, 5))
df_melted = df.melt(id_vars='Categoría', value_vars=['Valor1', 'Valor2'], var_name='Variable', value_name='Valor')
sns.barplot(x='Categoría', y='Valor', hue='Variable', data=df_melted, palette='muted')
plt.title('Media de Valor1 y Valor2 por Categoría', fontsize=14)
plt.xlabel('Categoría', fontsize=12)
plt.ylabel('Media', fontsize=12)
plt.legend(title='Variable')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# ## 8. Diagrama de Dispersión con Categorías (Seaborn)
# * Utiliza Seaborn para crear un diagrama de dispersión que muestre la relación entre 'Valor1' y 'Valor2',
# * diferenciando los puntos por 'Categoría' mediante colores.
# * Agrega un título al gráfico.

# %%
# Diagrama de dispersión con categorías para mostrar la relación entre 'Valor1' y 'Valor2'
plt.figure(figsize=(8, 5))
sns.scatterplot(x='Valor1', y='Valor2', hue='Categoría', data=df, palette='deep', s=100)
plt.title('Relación entre Valor1 y Valor2 diferenciada por Categoría', fontsize=14)
plt.xlabel('Valor1', fontsize=12)
plt.ylabel('Valor2', fontsize=12)
plt.legend(title='Categoría')
plt.grid(True, alpha=0.5)
plt.show()
